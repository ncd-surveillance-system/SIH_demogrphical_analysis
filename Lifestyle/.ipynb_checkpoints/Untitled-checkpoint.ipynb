# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
diabetes = pd.read_csv('lifestyle_dataset.csv')

# %%
diabetes.columns
# Out:
# Index(['ID of participants', 'Sex', 'Year of birth', 'Month of birth',
#        'Day of birth', 'Year of data', 'Time of data',
#        'Blood pressure_category', 'Triglyceride-category', 'HDL_category',
#        'LDL_category', 'GPT_category', 'g-GTP_category', 'HbA1c_category',
#        'Age', 'Living area ', 'Height', 'Weight', 'Waist circumference (cm)',
#        'BMI', 'Fasting blood glucose', 'HbA1c', 'Triglyceride', 'HDL', 'LDL',
#        'Systolic BP', 'Diastolic BP', 'Smoking status', 'healthgui_active',
#        'healthgui_motivation', 'GOT', 'GPT', 'γ-GTP', 'Uric acid',
#        'Urinary glucose', 'Serum creatinine', 'eGFR', 'Uric-pro',
#        'cardiograph', 'eyeground', 'Hematocrit', 'Hemoglobin',
#        'Taking health care from doctor_category', 'PHN_category',
#        'CI_category', 'Care-category', 'Unnamed: 46',
#        'Taking medication for hypertenstion',
#        'Taking medication for hyperlipidemia',
# ...

# %%
diabetes = diabetes.drop(['ID of participants', 'Year of birth', 'Month of birth', 'Day of birth', 'Year of data', 'Time of data', 'Fasting blood glucose', 'cardiograph', 'eyeground'], axis=1)

# %%
diabetes.dropna(how='any')
diabetes = diabetes.reset_index(drop=True)
print(diabetes)
diabetes.to_csv('Test.csv')
# Out:
#       Sex  Blood pressure_category  Triglyceride-category  HDL_category  \
# 0       0                        1                      1             1
# 1       0                        1                      1             1
# 2       0                        2                      1             1
# 3       0                        2                      1             1
# 4       0                        1                      1             1
# 5       0                        1                      1             1
# 6       0                        1                      1             1
# 7       0                        1                      1             1
# 8       1                        1                      1             2
# 9       0                        2                      1             1
# 10      1                        1                      1             1
# 11      0                        1                      1             1
# ...

# %%
diabetes['HbA1c_category'].replace([1], 0)
print(diabetes)
# Out:
#       Sex  Blood pressure_category  Triglyceride-category  HDL_category  \
# 0       0                        1                      1             1
# 1       0                        1                      1             1
# 2       0                        2                      1             1
# 3       0                        2                      1             1
# 4       0                        1                      1             1
# 5       0                        1                      1             1
# 6       0                        1                      1             1
# 7       0                        1                      1             1
# 8       1                        1                      1             2
# 9       0                        2                      1             1
# 10      1                        1                      1             1
# 11      0                        1                      1             1
# ...

# %%
neg,pos = diabetes['Taking medication for diabetes'].value_counts()

print ("Diabetes negatives:", neg)
print("Diabetes positives:", pos)
# Out:
# Diabetes negatives: 5440
# Diabetes positives: 714

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

diabetes = pd.read_csv('lifestyle_cleaned.csv')

#diabetes = diabetes.loc[:, diabetes.columns != 'Area']

X = np.array(diabetes.loc[:, diabetes.columns != 'Outcome'])  # 710x8
y = np.array(diabetes.loc[:, diabetes.columns == 'Outcome'])  # 710x1


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=37)

rf = RandomForestClassifier(n_estimators=1000, random_state= 77)
rf.fit(X_train, y_train.ravel())
score = rf.score(X_test, y_test)
    
print(score)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-148-75274983fb4e> in <module>
#      16
#      17 rf = RandomForestClassifier(n_estimators=1000, random_state= 77)
# ---> 18 rf.fit(X_train, y_train.ravel())
#      19 score = rf.score(X_test, y_test)
#      20
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     248
#     249         # Validate or convert input data
# --> 250         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     251         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     252         if sample_weight is not None:
#
# ...
