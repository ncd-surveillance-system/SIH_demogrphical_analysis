# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
diabetes = pd.read_csv('diabetes.csv')
print(diabetes.columns)
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
print('Dimensions:' , diabetes.shape)
# Out:
# Dimensions: (768, 9)

# %%
print(diabetes.groupby('Outcome').size())
# Out:
# Outcome
# 0    500
# 1    268
# dtype: int64

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
#Cleaning the data
diabetes = diabetes[diabetes.Outcome > 0]
diabetes = diabetes[diabetes.Glucose > 0]
diabetes = diabetes[diabetes.BloodPressure > 0]
diabetes = diabetes[diabetes.SkinThickness > 0]
diabetes = diabetes[diabetes.BMI > 0]
diabetes = diabetes[diabetes.DiabetesPedigreeFunction > 0]
diabetes = diabetes[diabetes.Age > 0]
diabetes = diabetes.reset_index(drop=True)

# %%
#New dimensions
print("Dimensions:", diabetes.shape)
# Out:
# Dimensions: (177, 9)

# %%
print(diabetes.describe())
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   177.000000  177.000000     177.000000     177.000000  177.000000
# mean      4.700565  143.118644      74.700565      32.977401  151.920904
# std       3.919017   31.265043      12.523870      10.395013  145.940035
# min       0.000000   78.000000      30.000000       7.000000    0.000000
# 25%       1.000000  118.000000      68.000000      27.000000    0.000000
# 50%       4.000000  144.000000      74.000000      32.000000  135.000000
# 75%       8.000000  171.000000      84.000000      39.000000  207.000000
# max      17.000000  199.000000     110.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age  Outcome
# count  177.000000                177.000000  177.000000    177.0
# mean    35.819774                  0.616588   36.412429      1.0
# std      6.611560                  0.398935   10.837355      0.0
# min     22.900000                  0.127000   21.000000      1.0
# 25%     31.600000                  0.328000   27.000000      1.0
# 50%     34.600000                  0.542000   35.000000      1.0
# 75%     38.500000                  0.787000   44.000000      1.0
# max     67.100000                  2.420000   70.000000      1.0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(diabetes.loc[:, diabetes.columns != 'Outcome'], diabetes['Outcome'], stratify=diabetes['Outcome'], random_state=66)

# %% [markdown]
# ## K-means

# %%
from sklearn.cluster import KMeans
X = np.array(diabetes.drop(['Outcome'], axis=1).astype(float))
y = np.array(diabetes['Outcome'])

# %%
kmeans = KMeans(n_clusters=4, max_iter=1000, algorithm = 'auto')
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=1000,
#     n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
pred = []

for i in range(len(X)):
    predict_me = np.array(X[i].astype(float))
    predict_me = predict_me.reshape(-1, len(predict_me))
    prediction = kmeans.predict(predict_me)
    pred.append("a"+str(prediction[0]))

# %%
diabetes['Area'] = pred

# %%
diabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              0      137             40             35      168  43.1
# 2              3       78             50             32       88  31.0
# 3              2      197             70             45      543  30.5
# 4              1      189             60             23      846  30.1
# 5              5      166             72             19      175  25.8
# 6              0      118             84             47      230  45.8
# 7              1      115             70             30       96  34.6
# 8              9      119             80             35        0  29.0
# 9             11      143             94             33      146  36.6
# 10            10      125             70             26      115  31.1
# 11             3      158             76             36      245  31.6
# 12             9      102             76             37        0  32.9
# 13             2       90             68             42        0  38.2
# 14             4      111             72             47      207  37.1
# 15             9      171            110             24      240  45.4
# 16             0      180             66             39        0  42.0
# 17             7      103             66             32        0  39.1
# 18             8      176             90             34      300  33.7
# 19             7      187             68             39      304  37.7
# 20             0      109             88             30        0  32.5
# 21             2      100             66             20       90  32.9
# 22            15      136             70             32      110  37.1
# 23             1      122             90             51      220  49.7
# 24             0       95             85             25       36  37.4
# 25             3      171             72             33      135  33.3
# 26             8      155             62             26      495  34.0
# 27             7      160             54             32      175  30.5
# 28             0      162             76             56      100  53.2
# 29             1       88             30             42       99  55.0
# ..           ...      ...            ...            ...      ...   ...
# 147            2      155             52             27      540  38.7
# 148            3       80             82             31       70  34.2
# 149            1      199             76             43        0  42.9
# 150            8      167            106             46      231  37.6
# 151            9      145             80             46      130  37.9
# 152            6      115             60             39        0  33.7
# 153            4      145             82             18        0  32.5
# 154           10      111             70             27        0  27.5
# 155            0      162             76             36        0  49.6
# 156            1      144             82             46      180  46.1
# 157            7      129             68             49      125  38.5
# 158            7      142             90             24      480  30.4
# 159            3      169             74             19      125  29.9
# 160            6      125             78             31        0  27.6
# 161            1      168             88             29        0  35.0
# 162            2       93             64             32      160  38.0
# 163           10      129             62             36        0  41.2
# 164            7      187             50             33      392  33.9
# 165            3      173             78             39      185  33.8
# 166            5       97             76             27        0  35.6
# 167            1      149             68             29      127  29.3
# 168            3      130             78             23       79  28.4
# 169            2      174             88             37      120  44.5
# 170           11      120             80             37      150  42.3
# 171            1      147             94             41        0  49.3
# 172            3      187             70             22      200  36.4
# 173            0      181             88             44      510  43.3
# 174            8      154             78             32        0  32.4
# 175            1      128             88             39      110  36.5
# 176            9      170             74             31        0  44.0
#
#      DiabetesPedigreeFunction  Age  Outcome Area
# 0                       0.627   50        1   a0
# 1                       2.288   33        1   a2
# 2                       0.248   26        1   a2
# 3                       0.158   53        1   a1
# 4                       0.398   59        1   a1
# 5                       0.587   51        1   a2
# 6                       0.551   31        1   a3
# 7                       0.529   32        1   a2
# 8                       0.263   29        1   a0
# 9                       0.254   51        1   a2
# 10                      0.205   41        1   a2
# 11                      0.851   28        1   a3
# 12                      0.665   46        1   a0
# 13                      0.503   27        1   a0
# 14                      1.390   56        1   a2
# 15                      0.721   54        1   a3
# 16                      1.893   25        1   a0
# 17                      0.344   31        1   a0
# 18                      0.467   58        1   a3
# 19                      0.254   41        1   a3
# 20                      0.855   38        1   a0
# 21                      0.867   28        1   a2
# 22                      0.153   43        1   a2
# 23                      0.325   31        1   a2
# 24                      0.247   24        1   a0
# 25                      0.199   24        1   a2
# 26                      0.543   46        1   a1
# 27                      0.588   39        1   a2
# 28                      0.759   25        1   a2
# 29                      0.496   26        1   a2
# ..                        ...  ...      ...  ...
# 147                     0.240   25        1   a1
# 148                     1.292   27        1   a0
# 149                     1.394   22        1   a0
# 150                     0.165   43        1   a3
# 151                     0.637   40        1   a2
# 152                     0.245   40        1   a0
# 153                     0.235   70        1   a0
# 154                     0.141   40        1   a0
# 155                     0.364   26        1   a0
# 156                     0.335   46        1   a2
# 157                     0.439   43        1   a2
# 158                     0.128   43        1   a1
# 159                     0.268   31        1   a2
# 160                     0.565   49        1   a0
# 161                     0.905   52        1   a0
# 162                     0.674   23        1   a2
# 163                     0.441   38        1   a0
# 164                     0.826   34        1   a3
# 165                     0.970   31        1   a2
# 166                     0.378   52        1   a0
# 167                     0.349   42        1   a2
# 168                     0.323   34        1   a0
# 169                     0.646   24        1   a2
# 170                     0.785   48        1   a2
# 171                     0.358   27        1   a0
# 172                     0.408   36        1   a2
# 173                     0.222   26        1   a1
# 174                     0.443   45        1   a0
# 175                     1.057   37        1   a2
# 176                     0.403   43        1   a0
#
# [177 rows x 10 columns]
